# %% [markdown]
# # Flight Dataset
# ## how to calculate for delay flight and visualize them

# %%
import pandas as pd

# %%
data = pd.read_csv('./datasets/airline-dataset/flights/flights.csv')
data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
from scipy import stats

# %%
stats.trim_mean(data['ArrDelay'], 0.1)
# Out:
# 0.8467375

# %%
data['ArrDelay'].mode()
# Out:
# 0   -6.0
# Name: ArrDelay, dtype: float64

# %%
data['ArrDelay'].median()
# Out:
# -2.0

# %%
data['ArrDelay'].var()
# Out:
# 958.95256658265

# %%
data['ArrDelay'].std()
# Out:
# 30.966959272467324

# %%
data['ArrDelay'].hist(bins=200)
# Out:
# <AxesSubplot:>

# %%
data['ArrDelay'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
# Normal Distribution (Gussian)
data['ArrDelay'][data['ArrDelay'] < 100].hist(bins=200)
# Out:
# <AxesSubplot:>

# %%
# agar dade haye ma ideal bashand (mean,median,mode) dar yek ja gharar migirad.

# %%
data['ArrDelay'][data['ArrDelay'] < 100].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
data['ArrDelay'].mean() - (3 * data['ArrDelay'].std())
# Out:
# -87.17092381630773

# %%
data['ArrDelay'].mean() + (3 * data['ArrDelay'].std())
# Out:
# 98.63083181849622

# %%
data['ArrDelay'].skew()
# Out:
# 4.036770191689667

# %%
data['ArrDelay'].kurtosis()
# Out:
# 26.050253655721416

# %%
# besiari az takhir parvaz ha hol o hush parvaz ha kam shodand
data.corr()
# Out:
#                    Year  Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# Year                NaN    NaN         NaN        NaN       NaN         NaN
# Month               NaN    NaN         NaN        NaN       NaN         NaN
# DayofMonth          NaN    NaN    1.000000  -0.119195 -0.001222    0.005302
# DayOfWeek           NaN    NaN   -0.119195   1.000000  0.031130    0.024901
# DepTime             NaN    NaN   -0.001222   0.031130  1.000000    0.985475
# CRSDepTime          NaN    NaN    0.005302   0.024901  0.985475    1.000000
# ArrTime             NaN    NaN   -0.004445   0.021947  0.796903    0.795609
# CRSArrTime          NaN    NaN   -0.000960   0.028391  0.852065    0.862598
# FlightNum           NaN    NaN    0.072934  -0.039755  0.023330    0.023253
# ActualElapsedTime   NaN    NaN    0.004568   0.015945 -0.069542   -0.074644
# CRSElapsedTime      NaN    NaN   -0.005462   0.016669 -0.066037   -0.069734
# ...
